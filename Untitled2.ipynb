# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
import tkinter as tk

data = pd.read_excel (r'C:\Users\MathiasUdsen\Desktop\Uni\4. Semester\Program\Opgave 2\Data0.xlsx')

# %%
# År
years = [2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]

# Total antal

antal_tot_1 = np.array(data.iloc[2,5:20])

#print(antal_tot_1)

# Alder

alder_1 = np.array(data.iloc[3:39,4])

#print(alder_1)


# Antal

i = np.array(range(15))
#print(i)
antal_test =  np.array(data.iloc[3:39,5+i])
antal = antal_test.transpose()
#print(antal)

# %%
# mænd i 411
z = np.array([0, 37, 37*2, 37*3 ,37*4, 37*5, 37*6, 37*7, 37*8, 37*9, 37*10])

np.ones(11)

alder_m = np.array(data.iloc[410+z[0]:446+z[0],4])

#print(alder_m)

antal_tot_m = np.array(data.iloc[409+z,5:20])

#print(antal_tot_m)

uddannelse_m = pd.Series(['Grundskole_m','Forberedende uddannelser_m','Gymnasiale uddannelser_m','Erhvervsfaglige grundforløb_m','Erhvervsfaglige uddannelser_m','Adgangsgivende uddannelsesforløb_m','KVU_m','MVU_m','BACH_m','LVU_m','Ph.d. og forskeruddannelser_m'])
uddannelse_k = pd.Series(['Grundskole_k','Forberedende uddannelser_k','Gymnasiale uddannelser_k','Erhvervsfaglige grundforløb_k','Erhvervsfaglige uddannelser_k','Adgangsgivende uddannelsesforløb_k','KVU_k','MVU_k','BACH_k','LVU_k','Ph.d. og forskeruddannelser_k'])

# %%
df_m = pd.DataFrame(
    antal_tot_m,
    columns = years,
    index = uddannelse_m
)
#print(df_m)
df_m.drop('Forberedende uddannelser_m', inplace=True)
df_m.drop('Erhvervsfaglige grundforløb_m', inplace=True)

df_m
# Out:
#                                        2005     2006     2007     2008  \
# Grundskole_m                        47223.0  48194.0  47444.0  50593.0
# Gymnasiale uddannelser_m            13641.0  13237.0  13652.0  14053.0
# Erhvervsfaglige uddannelser_m       14502.0  14826.0  15244.0  15514.0
# Adgangsgivende uddannelsesforløb_m    706.0    551.0    578.0    487.0
# KVU_m                                2703.0   2532.0   2798.0   2958.0
# MVU_m                                4439.0   4651.0   4540.0   4414.0
# BACH_m                               4714.0   4711.0   5369.0   5555.0
# LVU_m                                6026.0   6167.0   6491.0   5927.0
# Ph.d. og forskeruddannelser_m         600.0    507.0    635.0    673.0
#
#                                        2009     2010     2011     2012  \
# Grundskole_m                        50937.0  51821.0  53191.0  54278.0
# Gymnasiale uddannelser_m            15272.0  16202.0  17528.0  18899.0
# Erhvervsfaglige uddannelser_m       16213.0  17233.0  16796.0  16550.0
# Adgangsgivende uddannelsesforløb_m    533.0    740.0    836.0    828.0
# KVU_m                                2739.0   3122.0   3491.0   3848.0
# MVU_m                                4590.0   4430.0   4887.0   5051.0
# BACH_m                               5979.0   6187.0   6353.0   6509.0
# LVU_m                                6462.0   6319.0   6577.0   6971.0
# Ph.d. og forskeruddannelser_m         688.0    794.0    869.0    879.0
#
#                                        2013     2014     2015     2016  \
# Grundskole_m                        53660.0  53121.0  52567.0  53096.0
# Gymnasiale uddannelser_m            20267.0  21001.0  21019.0  21245.0
# Erhvervsfaglige uddannelser_m       15920.0  17337.0  15327.0  16631.0
# Adgangsgivende uddannelsesforløb_m    890.0    773.0    680.0    639.0
# KVU_m                                4300.0   4065.0   4487.0   4920.0
# MVU_m                                6227.0   6930.0   7605.0   8065.0
# BACH_m                               7291.0   7970.0   8350.0   9232.0
# LVU_m                                7288.0   7655.0   8627.0  11694.0
# Ph.d. og forskeruddannelser_m        1053.0   1150.0   1143.0   1151.0
#
#                                        2017     2018     2019
# Grundskole_m                        51632.0  51439.0  51863.0
# Gymnasiale uddannelser_m            21019.0  21597.0  21989.0
# Erhvervsfaglige uddannelser_m       16037.0  15864.0  14886.0
# Adgangsgivende uddannelsesforløb_m    643.0    564.0    418.0
# KVU_m                                4954.0   4986.0   5178.0
# MVU_m                                8185.0   8344.0   8260.0
# BACH_m                               8314.0   8402.0   8310.0
# LVU_m                               11078.0  10503.0  10348.0
# Ph.d. og forskeruddannelser_m        1159.0   1069.0      0.0

# %%
df_m.T.plot(kind = 'bar', stacked = True)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

plt.show()




# Kvinder 
alder_k = np.array(data.iloc[817+z[0]:853+z[0],4])

#print(alder_m)

antal_tot_k = np.array(data.iloc[816+z,5:20])

#print(antal_tot_m)

# %%
df_k = pd.DataFrame(
    antal_tot_k,
    columns = years,
    index = uddannelse_k
)
#print(df_k)

# Drop
df_k.drop('Erhvervsfaglige grundforløb_k', inplace=True)
df_k.drop('Forberedende uddannelser_k',inplace=True)

df_k
# Out:
#                                        2005     2006     2007     2008  \
# Grundskole_k                        46642.0  47440.0  46876.0  49605.0
# Gymnasiale uddannelser_k            18804.0  18092.0  18508.0  18751.0
# Erhvervsfaglige uddannelser_k       16848.0  16381.0  16561.0  16693.0
# Adgangsgivende uddannelsesforløb_k    250.0    256.0    280.0    249.0
# KVU_k                                2301.0   2250.0   2647.0   2775.0
# MVU_k                               11357.0  10613.0   9995.0  10007.0
# BACH_k                               5984.0   5986.0   6548.0   6896.0
# LVU_k                                6617.0   6659.0   7330.0   7170.0
# Ph.d. og forskeruddannelser_k         417.0    417.0    441.0    506.0
#
#                                        2009     2010     2011     2012  \
# Grundskole_k                        49778.0  51118.0  52042.0  52231.0
# Gymnasiale uddannelser_k            20087.0  20955.0  21966.0  23253.0
# Erhvervsfaglige uddannelser_k       16691.0  15528.0  15752.0  16783.0
# Adgangsgivende uddannelsesforløb_k    210.0    207.0    184.0    224.0
# KVU_k                                2655.0   2807.0   3207.0   3326.0
# MVU_k                               10545.0  10348.0  10128.0   9952.0
# BACH_k                               7650.0   8390.0   8014.0   8501.0
# LVU_k                                7657.0   7480.0   8043.0   8678.0
# Ph.d. og forskeruddannelser_k         540.0    664.0    726.0    776.0
#
#                                        2013     2014     2015     2016  \
# Grundskole_k                        51324.0  50349.0  50415.0  50655.0
# Gymnasiale uddannelser_k            24154.0  25163.0  25204.0  25306.0
# Erhvervsfaglige uddannelser_k       16379.0  16563.0  15744.0  16955.0
# Adgangsgivende uddannelsesforløb_k    250.0    217.0    198.0    175.0
# KVU_k                                3635.0   3846.0   4009.0   4450.0
# MVU_k                               11599.0  12522.0  13064.0  13417.0
# BACH_k                               9435.0   9734.0  10004.0  11106.0
# LVU_k                                9386.0  10149.0  11046.0  15162.0
# Ph.d. og forskeruddannelser_k         869.0   1020.0   1071.0   1078.0
#
#                                        2017     2018     2019
# Grundskole_k                        49199.0  48763.0  49180.0
# Gymnasiale uddannelser_k            24836.0  25897.0  26680.0
# Erhvervsfaglige uddannelser_k       16071.0  14333.0  11045.0
# Adgangsgivende uddannelsesforløb_k    192.0    241.0    191.0
# KVU_k                                4516.0   4348.0   4458.0
# MVU_k                               13360.0  13612.0  13735.0
# BACH_k                               9916.0  10010.0  10202.0
# LVU_k                               13970.0  13207.0  13414.0
# Ph.d. og forskeruddannelser_k        1084.0   1024.0      0.0

# %%
df_k.T.plot(kind = 'bar', stacked = True)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

plt.show()

# %%
# Appending
df_mk = df_m.append(df_k)

df_mk

df_m.T.plot(kind = 'bar', stacked = True)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

df_k.T.plot(kind = 'bar', stacked = True)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

plt.show()

# %%
i = np.array(range(15))
#print(i)
antal_test =  np.array(data.iloc[3:39,5+i])
antal = antal_test.transpose()
#print(antal)


#c = np.array(range(36))

x_1 = np.array(range(36))
x = sorted(x_1,reverse=True)



def v(x ,c = 36):
    return np.array(range(0, c-x))
def w(x):
    return sorted(v(x), reverse=True)
#print(w(0))

#def v:
#    if v>0:
#        return ()
#    if v < 0:
#        return
    


def antal_a_2005(x, i = 0):
    return np.array(data.iloc[3+v(x),5+i])


#def antal_a_2005(v, c = c, i = 0):
#    return np.array(data.iloc[3+c-v,5+i])

# %%
plt.plot(antal_a_2005(0))
plt.axis([-1, 36, -2000, 55000])


plt.show()
